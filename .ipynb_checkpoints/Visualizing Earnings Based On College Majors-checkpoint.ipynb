# %% [markdown]
# # Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
raw_data_count = recent_grads.count
raw_data_count
# Out:
# <bound method DataFrame.count of      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# ...

# %%
cleaned_data_count = recent_grads.dropna()
recent_grads
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %% [markdown]
# # Pandas, Scatter Plots

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample_size and Median')

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', color='red')
ax.set_title = ('Sample_size and Unemployment_rate')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', color='green', title='Full_time and Median')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen and Unemployment_rate')

# %%
ax = recent_grads.plot(x='Men', y='Median', kind='scatter', color='grey')
ax.set_title('Men and Median')
# Out:
# Text(0.5,1,'Men and Median')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women and Median', color='orange')

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=15, range=(10000, 150000), color='grey')

# %%
recent_grads['Employed'].hist(bins=15, range=(0, 40000), color='green')

# %% [markdown]
# ### Checking Full Time Values to Determine the scale of the Histogram

# %%
recent_grads['Full_time'].min(), recent_grads['Employed'].max()
# Out:
# (111, 307933)

# %%
recent_grads['Full_time'].hist(bins=45, range=(100, 31000), color='red')

# %%
recent_grads['Unemployment_rate'].min(), recent_grads['Unemployment_rate'].max()
# Out:
# (0.0, 0.177226407)

# %%
recent_grads['Unemployment_rate'].hist(bins=15, range=(0, 100), color='black')

# %%
recent_grads['Men'].min(), recent_grads['Men'].max()
# Out:
# (119.0, 173809.0)

# %%
recent_grads['Men'].hist(bins=200, range=(0, 180000), color='blue')

# %%
recent_grads['Women'].min(), recent_grads['Women'].max()
# Out:
# (0.0, 307087.0)

# %%
recent_grads['Women'].hist(bins=200, range=(0, 180000), color='pink')

# %% [markdown]
# # Pandas, Scatter Matrix Plot¶

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(5, 5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11df3b2e8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e059080>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %% [markdown]
# ## Next Steps:
#
# * Use a grouped bar plot to compare the number of men with the number of women in each category of majors.
# * Use a box plot to explore the distributions of median salaries and unemployment rate.
# * Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.
